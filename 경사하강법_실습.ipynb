# %% [markdown]
# #경사하강법 실습

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = [[2,81],[4,93],[6,91],[8,97]]
x = [i[0] for i in data]
y = [i[1] for i in data]

#그래프로 나타내기
plt.figure(figsize = (8,5))
plt.scatter(x,y)
plt.show()

#리스트로 되어 있는 x와 y의 값을 넘파이 배열로 바꾸기 (인덱스를 주어 하나씩 불러와 계산이 가능하게 하기 위함)
x_data = np.array(x)
y_data = np.array(y)

#기울기 a와 절편 b 초기화
a = 0
b = 0

#학습률 정하기 -> 수정해나갈 오차의 범위를 정해주는 것
lr = 0.03

#몇 번 반복될 지 설정(이차그래프에서 최소의 기울기 m값을 찾기 위해 몇번의 반복?)
epochs = 2001 

#경사하강법 시작
for i in range(epochs):
    y_pred = a*x_data +b #y에 대한 예측값 식 세우기
    error = y_data - y_pred #오차값 구하기 (실제값 - 예측값)
    
    #오차 함수를 a로 미분한 결과
    a_diff = -(1/len(x_data))*sum(x_data*(error))
    #오차 함수를 b로 미분한 결과
    b_diff = -(1/len(y_data))*sum(y_data-y_pred)
    
    a = a - lr * a_diff #학습률을 곱해 기존의 a값 업데이트 (미분한 값이 음수이면 a를 0보다 큰쪽으로 이동)
    b = b - lr * b_diff
    
    if i % 100 == 0: #100번 epochs일 때마다 알려주기
        print("epochs = %.f, 기울기 = %.04f, 절편 = %.04f" %(i,a,b))

y_pred = a*x_data +b
plt.scatter(x,y)
plt.plot([min(x_data),max(x_data)],[min(y_pred), max(y_pred)])
plt.show()
# Out:
# epochs = 0, 기울기 = 13.9200, 절편 = 2.7150
# epochs = 100, 기울기 = 10.1307, 절편 = 32.2700
# epochs = 200, 기울기 = 7.1088, 절편 = 50.3032
# epochs = 300, 기울기 = 5.2531, 절편 = 61.3774
# epochs = 400, 기울기 = 4.1135, 절편 = 68.1780
# epochs = 500, 기울기 = 3.4136, 절편 = 72.3542
# epochs = 600, 기울기 = 2.9839, 절편 = 74.9189
# epochs = 700, 기울기 = 2.7200, 절편 = 76.4938
# epochs = 800, 기울기 = 2.5579, 절편 = 77.4609
# epochs = 900, 기울기 = 2.4584, 절편 = 78.0549
# epochs = 1000, 기울기 = 2.3973, 절편 = 78.4196
# epochs = 1100, 기울기 = 2.3597, 절편 = 78.6436
# epochs = 1200, 기울기 = 2.3367, 절편 = 78.7811
# epochs = 1300, 기울기 = 2.3225, 절편 = 78.8656
# epochs = 1400, 기울기 = 2.3138, 절편 = 78.9175
# epochs = 1500, 기울기 = 2.3085, 절편 = 78.9493
# epochs = 1600, 기울기 = 2.3052, 절편 = 78.9689
# epochs = 1700, 기울기 = 2.3032, 절편 = 78.9809
# epochs = 1800, 기울기 = 2.3020, 절편 = 78.9883
# epochs = 1900, 기울기 = 2.3012, 절편 = 78.9928
# epochs = 2000, 기울기 = 2.3007, 절편 = 78.9956

# %%
new_data = 7
res = a*new_data + b

res
# Out:
# 95.10076588585352
