# %% [markdown]
# #다중 분류 문제 다루기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분입니다.
np.random.seed(3)
tf.random.set_seed(3)

# 데이터 입력
df = pd.read_csv('C:/Users/ksmin/Python_vs/DeepLearning/iris.csv', names=["special_length", "sepal_width", "petal_length", "petal_width", "species"])

# 그래프로 확인
sns.pairplot(df, hue='species');
plt.show()
# Out:
# C:\Users\ksmin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 데이터 분류
dataset = df.values
X = dataset[:,0:4].astype(float)
Y_obj = dataset[:,4]

# 문자열을 숫자로 변환
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)
Y_encoded = tf.keras.utils.to_categorical(Y)

# 모델의 설정
model = Sequential()
model.add(Dense(16,  input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 모델 컴파일
model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

# 모델 실행
model.fit(X, Y_encoded, epochs=50, batch_size=1)

# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X, Y_encoded)[1]))
# Out:
# Epoch 1/50
# 150/150 [==============================] - 2s 3ms/step - loss: 1.3208 - accuracy: 0.3533
# Epoch 2/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.7472 - accuracy: 0.8400
# Epoch 3/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.5928 - accuracy: 0.8800
# Epoch 4/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.5059 - accuracy: 0.8667
# Epoch 5/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.9200
# Epoch 6/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.3976 - accuracy: 0.9333
# Epoch 7/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.3617 - accuracy: 0.9267
# Epoch 8/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.3419 - accuracy: 0.9600
# Epoch 9/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.3193 - accuracy: 0.9400
# Epoch 10/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.3000 - accuracy: 0.9600
# Epoch 11/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.2785 - accuracy: 0.9467
# Epoch 12/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.2608 - accuracy: 0.9533
# Epoch 13/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.9600
# Epoch 14/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.2337 - accuracy: 0.9733
# Epoch 15/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.2207 - accuracy: 0.9600
# Epoch 16/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.2118 - accuracy: 0.9600
# Epoch 17/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.9667
# Epoch 18/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1958 - accuracy: 0.9467
# Epoch 19/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1767 - accuracy: 0.9733
# Epoch 20/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1672 - accuracy: 0.9667
# Epoch 21/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1590 - accuracy: 0.9667
# Epoch 22/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1559 - accuracy: 0.9533
# Epoch 23/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1453 - accuracy: 0.9733
# Epoch 24/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1421 - accuracy: 0.9667
# Epoch 25/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9733
# Epoch 26/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1265 - accuracy: 0.9733
# Epoch 27/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1296 - accuracy: 0.9800
# Epoch 28/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1067 - accuracy: 0.9933
# Epoch 29/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1208 - accuracy: 0.9667
# Epoch 30/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1171 - accuracy: 0.9667
# Epoch 31/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1109 - accuracy: 0.9733
# Epoch 32/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9667
# Epoch 33/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9667
# Epoch 34/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9600
# Epoch 35/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1025 - accuracy: 0.9600
# Epoch 36/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1010 - accuracy: 0.9600
# Epoch 37/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.0945 - accuracy: 0.9667
# Epoch 38/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0980 - accuracy: 0.9667
# Epoch 39/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.9800
# Epoch 40/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.1023 - accuracy: 0.9667
# Epoch 41/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.0903 - accuracy: 0.9733
# Epoch 42/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 0.9733
# Epoch 43/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.9733
# Epoch 44/50
# 150/150 [==============================] - 1s 3ms/step - loss: 0.0877 - accuracy: 0.9667
# Epoch 45/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0956 - accuracy: 0.9600
# Epoch 46/50
# 150/150 [==============================] - 1s 3ms/step - loss: 0.0886 - accuracy: 0.9733
# Epoch 47/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0907 - accuracy: 0.9533
# Epoch 48/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9667
# Epoch 49/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.0886 - accuracy: 0.9667
# Epoch 50/50
# 150/150 [==============================] - 0s 2ms/step - loss: 0.0922 - accuracy: 0.9533
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0779 - accuracy: 0.9733
#
#  Accuracy: 0.9733
